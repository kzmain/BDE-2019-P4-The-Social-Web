# %%
# !python3.6 -m pip install pysqlite3
# !python3.6 -m pip install textblob
# !python3.6 -m pip install GetOldTweets3
# !python3.6 -m pip install pandas
# !python3.6 -m pip install pyarrow

#!sudo apt-get install libsqlite3-dev
#!sudo apt-get install sqlite3

# %%
from textblob import TextBlob
from _sqlite3 import *
import re

def clean_tweet(tweet): 
        ''' 
        Utility function to clean tweet text by removing links, special characters 
        using simple regex statements. 
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 
    
def get_tweet_sentiment(tweet): 
        ''' 
        Utility function to classify sentiment of passed tweet 
        using textblob's sentiment method 
        '''
        # create TextBlob object of passed tweet text 
        analysis = TextBlob(tweet) 
        # set sentiment 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'

def get_tweet_tokens(tweet):
    tokens = [token for token in tweet.split()]
    return tokens

# %%
import GetOldTweets3 as got
import pandas as pd

# %%
df = pd.read_parquet("./data/Donald-Trump/Donald-Trump-2016-8-1.parquet.gzip")

# %%
# df = df["text"].unique()
df
# Out:
#                       id                                          permalink  \
# 0     760263815661576192  https://twitter.com/Complex/status/76026381566...
# 1     760263770174218240  https://twitter.com/Quixotic_Yawp/status/76026...
# 2     760263750792339456  https://twitter.com/splinter_news/status/76026...
# 3     760263693577908224  https://twitter.com/gdrcktimes/status/76026369...
# 4     760263337766772736  https://twitter.com/SocialInNewYork/status/760...
# ...                  ...                                                ...
# 3557  759901460855271424  https://twitter.com/sburke85/status/7599014608...
# 3558  759901459580383233  https://twitter.com/CharlieMarySays/status/759...
# 3559  759901459148308480  https://twitter.com/maw218/status/759901459148...
# 3560  759901458930212865  https://twitter.com/johnflat/status/7599014589...
# 3561  759901458284154880  https://twitter.com/BrightBlueWI/status/759901...
#
#              username               to  \
# 0             Complex             None
# 1       Quixotic_Yawp   MargaretAtwood
# 2       splinter_news             None
# 3          gdrcktimes  AlienRainforest
# 4     SocialInNewYork             None
# ...               ...              ...
# 3557         sburke85  realDonaldTrump
# 3558  CharlieMarySays  realDonaldTrump
# 3559           maw218             None
# 3560         johnflat          FoxNews
# 3561     BrightBlueWI     russfeingold
#
#                                                    text                date  \
# 0     Donald Trump had a historically awful conventi... 2016-08-01 23:59:53
# 1     The world is watching you shame yourself by be... 2016-08-01 23:59:42
# 2     "The remarks do not represent the views of our... 2016-08-01 23:59:37
# 3     lol, give one fact from Donald trump, and prov... 2016-08-01 23:59:24
# 4     KING: Stopping Donald Trump is a national emer... 2016-08-01 23:57:59
# ...                                                 ...                 ...
# 3557  I agree. Trump had nothing to do with Mr Khan'... 2016-08-01 00:00:01
# 3558  so you won a reality show? That's what this al... 2016-08-01 00:00:00
# 3559  @GOP @MichaelCohen212 @realDonaldTrump @seanha... 2016-08-01 00:00:00
# 3560  since when does the media focus on the real is... 2016-08-01 00:00:00
# 3561  @SenRonJohnson wants #DonaldTrump to be presid... 2016-08-01 00:00:00
#
#       retweets  favorites                                           mentions  \
# 0           33         79
# 1           15         34                                   @realDonaldTrump
# 2          128        151
# 3            0          0
# 4           71        117
# ...        ...        ...                                                ...
# 3557         0          0
# 3558         0          0
# 3559         0          0  @GOP @MichaelCohen212 @realDonaldTrump @seanha...
# 3560         0          0                   @realDonaldTrump @HillaryClinton
# 3561         0          0                       @SenRonJohnson @russfeingold
#
#                      hashtags geo
# 0
# 1            #GoldStarMothers
# 2
# 3
# 4
# ...                       ...  ..
# 3557
# 3558
# 3559
# 3560
# 3561  #DonaldTrump #Wisconsin
#
# [3562 rows x 11 columns]

# %%
df['text']     = df['text'].apply(clean_tweet)
df['positive'] = df['text'].apply(get_tweet_sentiment)
df['tokens']   = df['text'].apply(get_tweet_tokens)

# %%
# !python3.6 -m pip install nltk
# Out:
# Collecting nltk
# Collecting six (from nltk)
#   Using cached https://files.pythonhosted.org/packages/65/eb/1f97cb97bfc2390a276969c6fae16075da282f5058082d4cb10c6c5c1dba/six-1.14.0-py2.py3-none-any.whl
# Installing collected packages: six, nltk
# Successfully installed nltk-3.4.5 six-1.14.0

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
external_step_words = ['donald', 'trump', 'hillary', 'clinton', 'i', 'the', 'is', 'he', 'a', 'via', 'amp']

tokens = [token.lower() for li in list(df['tokens']) for token in li if token not in stop_words]
tokens = [token for token in tokens if token not in external_step_words]

# word not in stop_words
tokens
# type(stop_word)
# Out:
# [nltk_data] Downloading package stopwords to /home/tsw/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['historically',
#  'awful',
#  'convention',
#  'according',
#  'long',
#  'running',
#  'poll',
#  'world',
#  'watching',
#  'shame',
#  'belittling',
#  'military',
#  'goldstarmothers',
#  'remarks',
#  'represent',
#  'views',
#  'republican',
#  'party',
#  'even',
#  'gop',
#  'thinks',
#  'gone',
#  'far',
#  'lol',
#  'give',
#  'one',
#  'fact',
#  'prove',
#  'king',
#  'stopping',
#  'national',
#  'emergency',
#  'bet',
#  'pres',
#  'obama',
#  'smells',
#  'like',
#  'nice',
#  'cologne',
#  'probably',
#  'smells',
#  'like',
#  'rotten',
#  'cheeto',
#  'white',
#  'supremacy',
#  'trumpstory',
#  'sugarcoat',
#  'truth',
#  'tells',
#  'like',
#  'personally',
#  'love',
#  'go',
#  'policies',
#  'showushowtrump',
#  'khizr',
#  'khan',
#  'attack',
#  'goes',
#  'down',
#  'flames',
#  'dear',
#  'mr',
#  'kasich',
#  'we',
#  'people',
#  'would',
#  'like',
#  'town',
#  'hall',
#  'meeting',
#  'unite',
#  'party',
#  'rt',
#  'afraid',
#  'election',
#  'going',
#  'rigged',
#  'lied',
#  'well',
#  'complete',
#  'shock',
#  'who',
#  'capt',
#  'humayun',
#  'khan',
#  'parents',
#  'feuding',
#  'love',
#  'billionaires',
#  'throwing',
#  'shade',
#  'you',
#  'know',
#  'pisses',
#  'j',
#  'president',
#  'rally',
#  'harrisburg',
#  'pa',
#  'cumberland',
#  'valley',
#  'high',
#  'school',
#  'still',
#  'awaiting',
#  'mr',
#  'cool',
#  'man',
#  'pussies',
#  'way',
#  'better',
#  'one',
#  'america',
#  'respected',
#  'veterans',
#  'groups',
#  'condemned',
#  'nevertrump',
#  'gutless',
#  'refuses',
#  'release',
#  'tax',
#  'returns',
#  'avoided',
#  'vietnam',
#  'like',
#  'coward',
#  'what',
#  'small',
#  'shameless',
#  'man',
#  'president',
#  'obama',
#  'slams',
#  'over',
#  'gold',
#  'star',
#  'khan',
#  'family',
#  'clintonkaine2016',
#  'imwithher',
#  'nevertrump',
#  'uniteblue',
#  'not',
#  'only',
#  'pig',
#  'as',
#  'dumb',
#  'as',
#  'box',
#  'of',
#  'rocks',
#  'nevertrump',
#  'melaniatrump',
#  'clintonkaine2016',
#  'suggests',
#  'may',
#  'revoke',
#  'new',
#  'york',
#  'times',
#  'press',
#  'credentials',
#  'john',
#  'oliver',
#  'right',
#  'if',
#  'comfort',
#  'families',
#  'fallen',
#  'soldiers',
#  'fit',
#  'enter',
#  'white',
#  'house',
#  'even',
#  'guest',
#  'really',
#  'steaming',
#  'pile',
#  'now',
#  'warren',
#  'buffet',
#  'challenging',
#  'releaseyourtaxes',
#  'whatareyouhiding',
#  'how',
#  'stupid',
#  'party',
#  'created',
#  'muslim',
#  'american',
#  'women',
#  'are',
#  'using',
#  'this',
#  'powerful',
#  'hashtag',
#  'take',
#  'stand',
#  'against',
#  'starting',
#  'shortly',
#  'live',
#  'stream',
#  'rally',
#  'harrisburg',
#  'pa',
#  '8',
#  '1',
#  '16',
#  'manbaby',
#  'whining',
#  'already',
#  'desperate',
#  'afraid',
#  'election',
#  'going',
#  'to',
#  'be',
#  'rigged',
#  'top',
#  'american',
#  'historians',
#  'find',
#  'modern',
#  'way',
#  'rip',
#  'coward',
#  'lies',
#  'about',
#  'presidential',
#  'debates',
#  'afraid',
#  'debate',
#  'p2',
#  'takethewarrenbuffettchallenge',
#  'unless',
#  'afraid',
#  'j',
#  'screw',
#  'haters',
#  'they',
#  'follow',
#  'going',
#  'vote',
#  'liberals',
#  'lazy',
#  'happy',
#  'tonguetuesday',
#  'sorry',
#  'week',
#  'how',
#  'manafort',
#  'wielded',
#  'power',
#  'ukraine',
#  'before',
#  'advising',
#  'this',
#  'sketchy',
#  'af',
#  'blew',
#  'gt',
#  'convention',
#  'looks',
#  'like',
#  'failure',
#  'gop',
#  'fail',
#  'chants',
#  'we',
#  'want',
#  'large',
#  'crowd',
#  'waits',
#  'cumberland',
#  'valley',
#  'hs',
#  'khan',
#  'con',
#  'started',
#  'just',
#  'bashed',
#  'gold',
#  'star',
#  'muslim',
#  'couple',
#  'why',
#  'americans',
#  'don',
#  'care',
#  'nix',
#  'sees',
#  'true',
#  'billionaire',
#  'respect',
#  'well',
#  'cuban',
#  'gates',
#  'sure',
#  'actually',
#  'billionaire',
#  'like',
#  'madoff',
#  'planning',
#  'skip',
#  'presidential',
#  'debates',
#  'more',
#  'examples',
#  'sacrifice',
#  'attacks',
#  'cnn',
#  'tweetstorm',
#  'august',
#  '01',
#  'if',
#  'big',
#  'whip',
#  'freethe1040s',
#  'lgbtq',
#  'going',
#  'speak',
#  'russia',
#  'brutal',
#  'violent',
#  'homophobia',
#  'protect',
#  'us',
#  'one',
#  'foreign',
#  'ideology',
#  'ryan',
#  'cowardice',
#  'defined',
#  'forever',
#  'way',
#  'praises',
#  'paul',
#  'ryan',
#  'primary',
#  'opponent',
#  'ryan',
#  'stands',
#  'amid',
#  'khan',
#  'controversy',
#  'so',
#  'put',
#  'yet',
#  'give',
#  'insult',
#  'generator',
#  'try',
#  'ok',
#  'erratic',
#  'behaviour',
#  'raises',
#  'mental',
#  'health',
#  'questions',
#  'in',
#  'case',
#  'wondering',
#  'whether',
#  'pence',
#  'tell',
#  'size',
#  'lie',
#  'already',
#  'said',
#  'good',
#  'man',
#  'repeat',
#  'there',
#  'nothing',
#  'that',
#  'surprises',
#  'about',
#  'awful',
#  'did',
#  'you',
#  'know',
#  'what',
#  'difference',
#  'steaming',
#  'pile',
#  'shit',
#  'pile',
#  'shit',
#  'lying',
#  'racist',
#  'pig',
#  'how',
#  'face',
#  'debate',
#  'afraid',
#  'tweet',
#  'bbc',
#  'news',
#  'john',
#  'mccain',
#  'condemns',
#  'row',
#  'w',
#  'khan',
#  'family',
#  'all',
#  'thanked',
#  'khans',
#  'america',
#  'decent',
#  'warren',
#  'buffett',
#  'have',
#  'sense',
#  'decency',
#  'rabbi',
#  'mizrachi',
#  'talks',
#  'politics',
#  '2016',
#  'obama',
#  'republicans',
#  'with',
#  '98',
#  'days',
#  'left',
#  'campaign',
#  'unstable',
#  'continues',
#  'attack',
#  'ted',
#  'cruz',
#  'unity',
#  'something',
#  'passion',
#  'long',
#  'time',
#  'completely',
#  'consistent',
#  'richmond',
#  'warren',
#  'buffett',
#  'afraid',
#  'release',
#  'tax',
#  'returns',
#  'finally',
#  'good',
#  'news',
#  'beavis',
#  'butt',
#  'head',
#  'coming',
#  'back',
#  'mtv',
#  'watch',
#  'rally',
#  'in',
#  'harrisburg',
#  'pa',
#  'live',
#  'stream',
#  '8',
#  '1',
#  '16',
#  'now',
#  'let',
#  'end',
#  'moron',
#  'chances',
#  'beating',
#  'ga',
#  '4',
#  'prez',
#  'c',
#  'mon',
#  'atl',
#  'suburbs',
#  'win',
#  'trying',
#  'win',
#  'going',
#  'blow',
#  'gop',
#  'going',
#  'go',
#  'home',
#  'lol',
#  'racist',
#  'tramp',
#  'khan',
#  'confrontation',
#  'keys',
#  'human',
#  'decency',
#  'could',
#  'haunt',
#  'fareed',
#  'zakaria',
#  'calls',
#  'bulls',
#  'artist',
#  'on',
#  'live',
#  'television',
#  'love',
#  'khizr',
#  'khan',
#  'urges',
#  'join',
#  'hands',
#  'good',
#  'muslims',
#  'war',
#  'palm',
#  'beach',
#  'winter',
#  'white',
#  'house',
#  'plan',
#  'president',
#  'stirred',
#  'controversy',
#  'laughingstock',
#  'see',
#  'merriam',
#  'webster',
#  'years',
#  'fraud',
#  'not',
#  'paying',
#  'taxes',
#  'wants',
#  'defraud',
#  'america',
#  'prisoner',
#  'war',
#  'hero',
#  'john',
#  'mccain',
#  'john',
#  'mccain',
#  'condemns',
#  'row',
#  'khan',
#  'family',
#  'confirmed',
#  'newest',
#  'playable',
#  'upcoming',
#  'pok',
#  'mon',
#  'games',
#  'sun',
#  'moon',
#  'meet',
#  'mysterious',
#  'high',
#  'roller',
#  'wants',
#  'put',
#  'charge',
#  'food',
#  'muslims',
#  'michigan',
#  'defend',
#  'gold',
#  'star',
#  'family',
#  'feuding',
#  'canyouhearusnow',
#  'by',
#  'trumping',
#  'ignorance',
#  'xenophobia',
#  'sexism',
#  'racism',
#  'veils',
#  'elitism',
#  'poor',
#  'white',
#  'real',
#  'american',
#  'masses',
#  'from',
#  'parent',
#  'pakistani',
#  'born',
#  'man',
#  'died',
#  'fighting',
#  'u',
#  's',
#  'muslim',
#  'who',
#  'attacked',
#  'muslim',
#  'brot',
#  'afraid',
#  'election',
#  'going',
#  'rigged',
#  'canyounot',
#  'dear',
#  'mr',
#  'understand',
#  'best',
#  'but',
#  'comes',
#  'city',
#  'state',
#  'show',
#  'respect',
#  'please',
#  'control',
#  'hilliary',
#  'waiting',
#  'hang',
#  'supporter',
#  'khizr',
#  'khan',
#  'attack',
#  'gold',
#  'star',
#  'mother',
#  'disrespect',
#  'limits',
#  'hey',
#  'easy',
#  'come',
#  'budget',
#  'pay',
#  'subcontractors',
#  'in',
#  'bizarro',
#  'marxian',
#  'way',
#  'tapped',
#  'opiates',
#  'real',
#  'american',
#  'masses',
#  'xenophobic',
#  'patriotism',
#  'fear',
#  'race',
#  'sexism',
#  'watch',
#  'rally',
#  'in',
#  'harrisburg',
#  'pa',
#  'live',
#  'stream',
#  '8',
#  '1',
#  '16',
#  'now',
#  'america',
#  'great',
#  'right',
#  'dishonestmedia',
#  'khizr',
#  'khan',
#  'attack',
#  'goes',
#  'down',
#  'flames',
#  'trumppence16',
#  'neverhillary',
#  'maga',
#  'probably',
#  'looking',
#  'wife',
#  'number',
#  '4',
#  'and',
#  'blame',
#  'losing',
#  'watch',
#  'explains',
#  'loves',
#  'twitter',
#  'pic',
#  'twitter',
#  'com',
#  'eroj3tj1t7',
#  'khizr',
#  'khan',
#  'u',
#  's',
#  'constitutional',
#  'crisis',
#  'wins',
#  'presidency',
#  'getting',
#  'slammed',
#  'billionaires',
#  'way',
#  'money',
#  'politics',
#  'bernie',
#  'supporters',
#  'support',
#  'cares',
#  'we',
#  'people',
#  'maga',
#  'want',
#  'daughter',
#  'ivanka',
#  'sue',
#  'faced',
#  'sexual',
#  'harassment',
#  'work',
#  'before',
#  'working',
#  'paul',
#  'manafort',
#  'sought',
#  'bring',
#  'viktor',
#  'yanukovych',
#  'party',
#  'back',
#  'power',
#  'ukraine',
#  'believes',
#  'inconsistently',
#  'following',
#  'federal',
#  'law',
#  'makes',
#  'disability',
#  'rights',
#  'champion',
#  'john',
#  'oliver',
#  'obliterates',
#  'sociopathic',
#  'response',
#  'khan',
#  'family',
#  'did',
#  'executives',
#  'violate',
#  'cuban',
#  'embargo',
#  'multi',
#  'deferral',
#  'chickenhawk',
#  'ducked',
#  'service',
#  'bone',
#  'spurs',
#  'golfed',
#  'others',
#  'died',
#  'one',
#  'thing',
#  'really',
#  'hashed',
#  'owns',
#  'least',
#  'three',
#  '3',
#  'gold',
#  'thrones',
#  'home',
#  'btw',
#  'bothered',
#  'mr',
#  'khan',
#  'bothers',
#  'us',
#  'gutless',
#  'soulless',
#  'nothing',
#  'kahn',
#  'death',
#  'parents',
#  'attacked',
#  'hrc',
#  'hit',
#  'mom',
#  '8000',
#  'and',
#  'rising',
#  'fast',
#  'live',
#  'stream',
#  'rally',
#  'harrisburg',
#  'pa',
#  '8',
#  '1',
#  '16',
#  'decisions',
#  'led',
#  'deaths',
#  'many',
#  'accepted',
#  'business',
#  'linked',
#  'isis',
#  'silence',
#  'rt',
#  'gosh',
#  'escalating',
#  'saying',
#  'khizr',
#  'khan',
#  'sympathetic',
#  'islamic',
#  'terrorists',
#  'one',
#  'positions',
#  'right',
#  'smack',
#  'gop',
#  'mainstream',
#  'blatant',
#  'irrational',
#  'explicit',
#  'climate',
#  'denial',
#  'show',
#  'taxes',
#  'crooked',
#  'j',
#  'you',
#  'not',
#  'paying',
#  'taxes',
#  'only',
#  'dreams',
#  'if',
#  'presidential',
#  'working',
#  '4',
#  'businessman',
#  'close',
#  'hearing',
#  'phrase',
#  'you',
#  'fired',
#  'hired',
#  'me',
#  'as',
#  'an',
#  'attorney',
#  'please',
#  'don',
#  'support',
#  'him',
#  'for',
#  'president',
#  'media',
#  'don',
#  'let',
#  'media',
#  'fool',
#  'americans',
#  'voting',
#  'business',
#  'man',
#  'alwaystrump',
#  'general',
#  'election',
#  'afraid',
#  'election',
#  'going',
#  'rigged',
#  'manbaby',
#  'crying',
#  'one',
#  'nice',
#  'waahh',
#  'pick',
#  'ur',
#  'balls',
#  'already',
#  '250',
#  'people',
#  'places',
#  'things',
#  'has',
#  'insulted',
#  'twitter',
#  'complete',
#  'list',
#  'new',
#  'york',
#  'times',
#  'breaking',
#  'news',
#  'calling',
#  'upon',
#  'immediately',
#  'stop',
#  'playing',
#  'margaritaville',
#  'loves',
#  'torturing',
#  'paul',
#  'ryan',
#  'praises',
#  'gop',
#  'opponent',
#  'not',
#  'late',
#  'get',
#  'back',
#  'away',
#  'getting',
#  'slammed',
#  'billionaires',
#  'way',
#  'money',
#  'timkaine',
#  'why',
#  'would',
#  'one',
#  'person',
#  'believe',
#  'rich',
#  'claims',
#  'pay',
#  'fair',
#  'share',
#  'taxes',
#  'charitable',
#  'says',
#  'prove',
#  'wrong',
#  'live',
#  'stream',
#  'rally',
#  'harrisburg',
#  'pa',
#  '8',
#  '1',
#  '16',
#  'et',
#  'trumppence16',
#  'companies',
#  'sought',
#  'import',
#  '1',
#  '100',
#  'immigrant',
#  'workers',
#  'report',
#  'washington',
#  'times',
#  'they',
#  'look',
#  'like',
#  'would',
#  'totally',
#  'marry',
#  'leading',
#  '9',
#  'points',
#  'new',
#  'national',
#  'poll',
#  'breaking',
#  'merkel',
#  'loosing',
#  'control',
#  'country',
#  'refugees',
#  'swarming',
#  'must',
#  'vote',
#  'greta',
#  'alaska',
#  'gop',
#  'sen',
#  'lisa',
#  'murkowski',
#  'must',
#  'honor',
#  'respect',
#  'gold',
#  'star',
#  'families',
#  'mr',
#  'kahn',
#  'some',
#  'good',
#  'hearted',
#  'sincere',
#  ...]

# %%
# !python3.6 -m pip install prettytable
# Out:
# Collecting prettytable
#   Downloading https://files.pythonhosted.org/packages/ef/30/4b0746848746ed5941f052479e7c23d2b56d174b82f4fd34a25e389831f5/prettytable-0.7.2.tar.bz2
# Building wheels for collected packages: prettytable
#   Running setup.py bdist_wheel for prettytable ... done
#   Stored in directory: /home/tsw/.cache/pip/wheels/80/34/1c/3967380d9676d162cb59513bd9dc862d0584e045a162095606
# Successfully built prettytable
# Installing collected packages: prettytable
# Successfully installed prettytable-0.7.2

# %%
df_tokens = pd.DataFrame(tokens, columns=['tokens'])

# df_tokens = pd.DataFrame(, columns=['tokens'])
df_tokens = df_tokens.groupby(['tokens']).size().reset_index(name='counts')
df_tokens = df_tokens.sort_values('counts', ascending=False)
df_tokens
# Out:
#              tokens  counts
# 2877           khan     356
# 3436         muslim     201
# 5929            you     182
# 1974         family     175
# 4004      president     137
# ...             ...     ...
# 2621     immigrated       1
# 2623      impartial       1
# 2624        impeach       1
# 2625  impersonation       1
# 5954           zone       1
#
# [5955 rows x 2 columns]

# %%
from prettytable import PrettyTable
from collections import Counter


# for label, data in (('Token', tokens)):
pt = PrettyTable(field_names=['Token', 'Count'])
c = Counter(tokens)
[ pt.add_row(kv) for kv in c.most_common()]
pt.align['Token'], pt.align['Count'] = 'l', 'r' # Set column alignment
# print(pt) 

print(type(pt))
#https://stackoverflow.com/questions/46527086/how-to-remove-stopwords-from-common-words-list-in-python
# Out:
# <class 'prettytable.PrettyTable'>

# %%
df = pd.DataFrame(pt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-476035164816> in <module>
# ----> 1 df = pd.DataFrame(pt)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                 )
#     508             else:
# --> 509                 raise ValueError("DataFrame constructor not properly called!")
#     510
#     511         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
df.groupby(['positive']).size()
# Out:
# positive
# negative     752
# neutral     1742
# positive    1068
# dtype: int64

# %%
# !python3.6 -m pip install pillow
# !python3.6 -m pip install wordcloud
# Out:
# Collecting pillow
#   Downloading https://files.pythonhosted.org/packages/19/5e/23dcc0ce3cc2abe92efd3cd61d764bee6ccdf1b667a1fb566f45dc249953/Pillow-7.0.0-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#     100% |████████████████████████████████| 2.1MB 611kB/s ta 0:00:011
# Installing collected packages: pillow
# Successfully installed pillow-7.0.0
# Collecting wordcloud
#   Downloading https://files.pythonhosted.org/packages/7b/f3/1017ea53d88cf39cc06139be4e021d99e3972d6cf635c8598c4cbecbbed0/wordcloud-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (361kB)
#     100% |████████████████████████████████| 368kB 1.7MB/s ta 0:00:011
# Collecting pillow (from wordcloud)
#   Using cached https://files.pythonhosted.org/packages/19/5e/23dcc0ce3cc2abe92efd3cd61d764bee6ccdf1b667a1fb566f45dc249953/Pillow-7.0.0-cp36-cp36m-manylinux1_x86_64.whl
# Collecting numpy>=1.6.1 (from wordcloud)
#   Using cached https://files.pythonhosted.org/packages/62/20/4d43e141b5bc426ba38274933ef8e76e85c7adea2c321ecf9ebf7421cedf/numpy-1.18.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting matplotlib (from wordcloud)
#   Downloading https://files.pythonhosted.org/packages/7e/07/4b361d6d0f4e08942575f83a11d33f36897e1aae4279046606dd1808778a/matplotlib-3.1.3-cp36-cp36m-manylinux1_x86_64.whl (13.1MB)
#     100% |████████████████████████████████| 13.1MB 128kB/s eta 0:00:01
# Collecting cycler>=0.10 (from matplotlib->wordcloud)
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib->wordcloud)
#   Downloading https://files.pythonhosted.org/packages/5d/bc/1e58593167fade7b544bfe9502a26dc860940a79ab306e651e7f13be68c2/pyparsing-2.4.6-py2.py3-none-any.whl (67kB)
#     100% |████████████████████████████████| 71kB 7.4MB/s eta 0:00:01
# Collecting python-dateutil>=2.1 (from matplotlib->wordcloud)
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# Collecting kiwisolver>=1.0.1 (from matplotlib->wordcloud)
#   Downloading https://files.pythonhosted.org/packages/f8/a1/5742b56282449b1c0968197f63eae486eca2c35dcd334bab75ad524e0de1/kiwisolver-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (90kB)
#     100% |████████████████████████████████| 92kB 8.3MB/s eta 0:00:01
# Collecting six (from cycler>=0.10->matplotlib->wordcloud)
#   Using cached https://files.pythonhosted.org/packages/65/eb/1f97cb97bfc2390a276969c6fae16075da282f5058082d4cb10c6c5c1dba/six-1.14.0-py2.py3-none-any.whl
# Collecting setuptools (from kiwisolver>=1.0.1->matplotlib->wordcloud)
#   Downloading https://files.pythonhosted.org/packages/3d/72/1c1498c1e908e0562b1e1cd30012580baa7d33b5b0ffdbeb5fde2462cc71/setuptools-45.2.0-py3-none-any.whl (584kB)
#     100% |████████████████████████████████| 593kB 2.5MB/s eta 0:00:01
# Installing collected packages: pillow, numpy, six, cycler, pyparsing, python-dateutil, setuptools, kiwisolver, matplotlib, wordcloud
# Successfully installed cycler-0.10.0 kiwisolver-1.1.0 matplotlib-3.1.3 numpy-1.18.1 pillow-7.0.0 pyparsing-2.4.6 python-dateutil-2.8.1 setuptools-45.2.0 six-1.14.0 wordcloud-1.6.0

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

comment_words = ' '
for words in tokens: 
    comment_words = comment_words + words + ' '

wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white').generate(comment_words) 
  
    
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show() 
# # https://www.geeksforgeeks.org/generating-word-cloud-python/

# %% [markdown]
# # Appendix
# [1] **Twitter Sentiment Analysis using Python,**, *https://www.geeksforgeeks.org/twitter-sentiment-analysis-using-python/*
